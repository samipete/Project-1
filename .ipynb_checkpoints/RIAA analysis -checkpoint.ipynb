# %%
# Import dependencies 
import pandas as pd
import matplotlib.pyplot as plt

# %%
artist_file =pd.read_csv("Resources/artistDf.csv")

artist_file.head()
# Out:
#    X          Artist  Followers  \
# 0  0      Ed Sheeran   52698756
# 1  1   Justin Bieber   30711450
# 2  2  Jonas Brothers    3069527
# 3  3           Drake   41420478
# 4  4     Chris Brown    9676862
#
#                                               Genres  NumAlbums  \
# 0                                         pop,uk pop          8
# 1           canadian pop,dance pop,pop,post-teen pop         10
# 2               boy band,dance pop,pop,post-teen pop         10
# 3  canadian hip hop,canadian pop,hip hop,pop rap,...         11
# 4                      dance pop,pop,pop rap,r&b,rap          6
#
#    YearFirstAlbum Gender Group.Solo
# 0            2011      M       Solo
# 1            2009      M       Solo
# 2            2006      M      Group
# 3            2010      M       Solo
# 4            2005      M       Solo

# %%
artist_gender = artist_file['Gender'].value_counts()
colors = ['cornflowerblue','lightcoral']
artist_gender.plot(kind='pie', autopct="%.1f%%", colors=colors)
plt.title('Male vs. Female Distribution of artists')

plt.show()

# %%
# import artist file 
file = "Resources/artistDf.csv"
artists=pd.read_csv(file)
artists.head()
# Out:
#    X          Artist  Followers  \
# 0  0      Ed Sheeran   52698756
# 1  1   Justin Bieber   30711450
# 2  2  Jonas Brothers    3069527
# 3  3           Drake   41420478
# 4  4     Chris Brown    9676862
#
#                                               Genres  NumAlbums  \
# 0                                         pop,uk pop          8
# 1           canadian pop,dance pop,pop,post-teen pop         10
# 2               boy band,dance pop,pop,post-teen pop         10
# 3  canadian hip hop,canadian pop,hip hop,pop rap,...         11
# 4                      dance pop,pop,pop rap,r&b,rap          6
#
#    YearFirstAlbum Gender Group.Solo
# 0            2011      M       Solo
# 1            2009      M       Solo
# 2            2006      M      Group
# 3            2010      M       Solo
# 4            2005      M       Solo

# %%
#import RIAA certifications file
file_2="Resources/riaaAlbumCerts_1999-2019.csv"
riaa=pd.read_csv(file_2)
riaa.head()
# Out:
#    Unnamed: 0                    Album        Artist             Status  \
# 0           0            GREATEST HITS  MARIAH CAREY  2x Multi-Platinum
# 1           1              THE REMIXES  MARIAH CAREY               Gold
# 2           2                    VIEWS         DRAKE  6x Multi-Platinum
# 3           3                MAJOR KEY     DJ KHALED        1x Platinum
# 4           4   THE CHRISTMAS SESSIONS       MERCYME               Gold
#
#                                                Label
# 0                                             LEGACY
# 1                                           COLUMBIA
# 2   REPUBLIC RECORDS / CASH MONEY RECORDS / YOUNG...
# 3                                 WE THE BEST / EPIC
# 4                                FAIR TRADE SERVICES

# %%
# Top 5 artists by followers 
#show only artist and followers column 
followers=artists[["Artist","Followers"]]
followers
# Out:
#                Artist  Followers
# 0          Ed Sheeran   52698756
# 1       Justin Bieber   30711450
# 2      Jonas Brothers    3069527
# 3               Drake   41420478
# 4         Chris Brown    9676862
# ...               ...        ...
# 1030    Dwight Yoakam     284597
# 1031    Jordan Knight      47229
# 1032      Lila McCann      42444
# 1033         Everlast     200550
# 1034  Collective Soul     525701
#
# [1035 rows x 2 columns]

# %%
#sort the followers column from greatest to smallest 
followers=followers.sort_values(["Followers"],ascending=False)
followers
# Out:
#                 Artist  Followers
# 0           Ed Sheeran   52698756
# 3                Drake   41420478
# 113            Rihanna   34436700
# 1        Justin Bieber   30711450
# 54              Eminem   30220119
# ...                ...        ...
# 888               Toya       2425
# 652     Jeannie Ortega       1442
# 972     Eric Heatherly       1093
# 1029      Terry Dexter        790
# 572   Down A.K.A. Kilo        775
#
# [1035 rows x 2 columns]

# %%
#display top 5 artists by followers and reset index
followers=followers.head()
followers.reset_index(drop=True,inplace=True)
followers=followers.set_index(["Artist"])
followers
# Out:
#                Followers
# Artist
# Ed Sheeran      52698756
# Drake           41420478
# Rihanna         34436700
# Justin Bieber   30711450
# Eminem          30220119

# %%
#create bar chart
followers.plot(kind="bar",title="5 Most Followed Artist on Spotify", xlabel="Artist", ylabel="Number of Followers" )
plt.show()

# %%
# Which artist has released the most albums 
#look only at the artist and NumAlbum colums 
most_album=artists[["Artist","NumAlbums"]]
most_album
# Out:
#                Artist  NumAlbums
# 0          Ed Sheeran          8
# 1       Justin Bieber         10
# 2      Jonas Brothers         10
# 3               Drake         11
# 4         Chris Brown          6
# ...               ...        ...
# 1030    Dwight Yoakam         25
# 1031    Jordan Knight          4
# 1032      Lila McCann          4
# 1033         Everlast         11
# 1034  Collective Soul         12
#
# [1035 rows x 2 columns]

# %%
#sort the dataframe by Number of albums from greatest to least 
most_album=most_album.sort_values(["NumAlbums"],ascending=False)
most_album
# Out:
#                    Artist  NumAlbums
# 25             Gucci Mane        132
# 682         Willie Nelson        112
# 245             Cash Cash         91
# 861             Oakenfold         90
# 67          Elvis Presley         75
# ..                    ...        ...
# 680  The Notorious B.I.G.          3
# 356            Steve Holy          3
# 955        Changing Faces          3
# 812           Fefe Dobson          3
# 637           Nick Lachey          3
#
# [1035 rows x 2 columns]

# %%
#reset the index
most_album.reset_index(drop=True,inplace=True)
most_album
# Out:
#                     Artist  NumAlbums
# 0               Gucci Mane        132
# 1            Willie Nelson        112
# 2                Cash Cash         91
# 3                Oakenfold         90
# 4            Elvis Presley         75
# ...                    ...        ...
# 1030  The Notorious B.I.G.          3
# 1031            Steve Holy          3
# 1032        Changing Faces          3
# 1033           Fefe Dobson          3
# 1034           Nick Lachey          3
#
# [1035 rows x 2 columns]

# %%
#display the artist with the most albums 
name_most_album=most_album.iloc[[0]]
name_most_album
# Out:
#        Artist  NumAlbums
# 0  Gucci Mane        132

# %%
#which artist relseased the first album
year=artists[["Artist","YearFirstAlbum"]]
year
# Out:
#                Artist  YearFirstAlbum
# 0          Ed Sheeran            2011
# 1       Justin Bieber            2009
# 2      Jonas Brothers            2006
# 3               Drake            2010
# 4         Chris Brown            2005
# ...               ...             ...
# 1030    Dwight Yoakam            1985
# 1031    Jordan Knight            1999
# 1032      Lila McCann            1997
# 1033         Everlast            1990
# 1034  Collective Soul            1994
#
# [1035 rows x 2 columns]

# %%
#sort by eariest year release 
year=year.sort_values(["YearFirstAlbum"])
year
# Out:
#               Artist  YearFirstAlbum
# 63        Gene Autry            1929
# 66       Bing Crosby            1932
# 71     Frank Sinatra            1946
# 58         Burl Ives            1949
# 361     Tony Bennett            1952
# ..               ...             ...
# 279            Q-Tip            2011
# 43   Scotty McCreery            2011
# 202   Action Bronson            2011
# 214              Big            2011
# 0         Ed Sheeran            2011
#
# [1035 rows x 2 columns]

# %%
#reset index
year.reset_index(drop=True, inplace=True)
year
# Out:
#                Artist  YearFirstAlbum
# 0          Gene Autry            1929
# 1         Bing Crosby            1932
# 2       Frank Sinatra            1946
# 3           Burl Ives            1949
# 4        Tony Bennett            1952
# ...               ...             ...
# 1030            Q-Tip            2011
# 1031  Scotty McCreery            2011
# 1032   Action Bronson            2011
# 1033              Big            2011
# 1034       Ed Sheeran            2011
#
# [1035 rows x 2 columns]

# %%
#distplay the artist 
year_dropped=year.iloc[[0]]
year_dropped
# Out:
#        Artist  YearFirstAlbum
# 0  Gene Autry            1929

# %%
#plot the first 5 albums dropped by year
df=year.set_index(['Artist'])
df=df.head()
df
# Out:
#                YearFirstAlbum
# Artist
# Gene Autry               1929
# Bing Crosby              1932
# Frank Sinatra            1946
# Burl Ives                1949
# Tony Bennett             1952

# %%
#drop unwanted columns
riaa=riaa.drop(["Unnamed: 0"],axis=1)
riaa
# Out:
#                          Album        Artist             Status  \
# 0                GREATEST HITS  MARIAH CAREY  2x Multi-Platinum
# 1                  THE REMIXES  MARIAH CAREY               Gold
# 2                        VIEWS         DRAKE  6x Multi-Platinum
# 3                    MAJOR KEY     DJ KHALED        1x Platinum
# 4       THE CHRISTMAS SESSIONS       MERCYME               Gold
# ...                        ...           ...                ...
# 1726      THE DISTANCE TO HERE          LIVE        1x Platinum
# 1727             I WANT IT ALL      WARREN G               Gold
# 1728         TO VENUS AND BACK     TORI AMOS        1x Platinum
# 1729          GUERILLA WARFARE      HOT BOYS        1x Platinum
# 1730  MURDA MUZIK / MOBB MUZIK     MOBB DEEP        1x Platinum
#
#                                                   Label
# 0                                                LEGACY
# 1                                              COLUMBIA
# 2      REPUBLIC RECORDS / CASH MONEY RECORDS / YOUNG...
# 3                                    WE THE BEST / EPIC
# 4                                   FAIR TRADE SERVICES
# ...                                                 ...
# 1726                                        RADIOACTIVE
# 1727                                    RESTLESS/G-FUNK
# 1728                                           ATLANTIC
# 1729                                         CASH MONEY
# 1730                                               LOUD
#
# [1731 rows x 4 columns]

# %%
#Label with most albums released
label=riaa["Label"].value_counts()
bar=label.head()
bar.plot(kind="bar", title="Label Generating Most Albums", xlabel="Label", ylabel="Number of Albums")
plt.show()

# %%
index=riaa.set_index(["Label"])
index
test=index["Status"]=="Gold"
test
df=index.loc[test[:]]
df
# Out:
#                                            Album             Artist Status
# Label
#  COLUMBIA                            THE REMIXES       MARIAH CAREY   Gold
#  FAIR TRADE SERVICES      THE CHRISTMAS SESSIONS            MERCYME   Gold
#  RCA                                    BAPTIZED           DAUGHTRY   Gold
#  ATLANTIC RECORDS            TREMAINE: THE ALBUM         TREY SONGZ   Gold
#  RCA                                    GRAFFITI        CHRIS BROWN   Gold
# ...                                          ...                ...    ...
#  GEFFEN                         MIDNITE VULTURES               BECK   Gold
#  ARISTA               RAVE UN2 THE JOY FANTASTIC             PRINCE   Gold
#  ELEKTRA                            NIGGA PLEASE  OL' DIRTY BASTARD   Gold
#  CAPRICORN                          SOUND SYSTEM                311   Gold
#  RESTLESS/G-FUNK                   I WANT IT ALL           WARREN G   Gold
#
# [742 rows x 3 columns]

# %%
df.set_index(["Artist"])
# Out:
#                                         Album Status
# Artist
# MARIAH CAREY                      THE REMIXES   Gold
# MERCYME                THE CHRISTMAS SESSIONS   Gold
# DAUGHTRY                             BAPTIZED   Gold
# TREY SONGZ                TREMAINE: THE ALBUM   Gold
# CHRIS BROWN                          GRAFFITI   Gold
# ...                                       ...    ...
# BECK                         MIDNITE VULTURES   Gold
# PRINCE             RAVE UN2 THE JOY FANTASTIC   Gold
# OL' DIRTY BASTARD                NIGGA PLEASE   Gold
# 311                              SOUND SYSTEM   Gold
# WARREN G                        I WANT IT ALL   Gold
#
# [742 rows x 2 columns]
